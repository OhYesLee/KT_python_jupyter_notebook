# %% [markdown]
# # 안녕하세요^^
# ## AIVLE 미니프로젝트 '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!
#
# ## 개인과제
# * 데이터 구조, 분포 확인, 전처리 : 1.1_버스정류장데이터 / 1.2 유동인구데이터 / 1.3_주민등록데이터 / 1.4_업종등록데이터
# * 데이터간 관계 가설 수립 및 검증 : 1.5_데이터 분석

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ## "구별 업종 등록 데이터" 를 확인해 보도록 하겠습니다

# %%
# 필요 라이브러리부터 설치합니다.
# %pip install pandas seaborn

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 기본/추가 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * business_type.csv
#
# [데이터 소개]
# * 서울 시 구별 등록 업종 상위 10개 데이터
#     * 택시운송업
#     * 한식일반음식점업
#     * 용달 화물자동차 운송업
#     * 부동산 중개 및 대리업
#     * 두발미용업
#     * 커피전문점
#     * 남녀용 겉옷 및 셔츠 도매업
#     * 기타주점업
#     * 일반 교과 학원
#     * 한식 육류요리 전문점
#
# [변수 소개]
# * 다수 업종 상위 1~10

# %% [markdown]
# ---

# %% [markdown]
# # 1.데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 파이썬의 모든 객체를 파일로 저장할 수 있는 방법으로 DataFrame,List,Dict 등 모든 객체 저장 가능(특히 sklearn라이브러리를 통해 모델을 학습시키고, 저장할 때 많이 사용)

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * 1.4 business_type.csv
#
# [데이터 소개]
# * 서울시 업종 등록 데이터

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * '1.4 business_type.csv'파일을 'seoul_business' 변수에 저장하고 그 데이터를 확인하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * UTF-8 인코더를 사용해 주세요

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import pandas as pd
seoul_business = pd.read_csv('1.4 business_type.csv', sep=",", encoding = "UTF-8", header=1)
seoul_business
# Out:
#      자치구     동   택시운송업 택시운송업.1 한식 일반 음식점업 한식 일반 음식점업.1 용달 화물자동차 운송업  \
# 0    자치구     동    사업체수    종사자수       사업체수         종사자수         사업체수
# 1     합계    합계  47,176  76,701     29,225      100,183       28,494
# 2    종로구    소계     215     215      1,548        5,912          618
# 3    종로구   사직동       7       7        230          982           12
# 4    종로구   삼청동       5       5         42          145            4
# ..   ...   ...     ...     ...        ...          ...          ...
# 445  강동구  성내3동     120     120        135          390           73
# 446  강동구  둔촌2동     117     436         63          249           89
# 447  강동구  암사1동     209     372         71          195          153
# 448  강동구  천호2동     157     187        152          509          144
# 449  강동구    길동   1,441   1,557        152          436          217
#
#     용달 화물자동차 운송업.1 부동산 중개 및 대리업 부동산 중개 및 대리업.1  ...   커피전문점 커피전문점.1  \
# 0             종사자수         사업체수           종사자수  ...    사업체수    종사자수
# 1           29,356       24,013         42,636  ...  16,255  57,322
# 2              646          549            889  ...     948   3,613
# 3               12           57             96  ...     124     525
# 4                4            9             10  ...      66     243
# ..             ...          ...            ...  ...     ...     ...
# 445             73          104            163  ...      54     133
# 446             89           61            108  ...      34      85
# 447            153           67            107  ...      29      59
# 448            151           97            188  ...      63     212
# 449            225          146            237  ...      71     228
#
#     남녀용 겉옷 및 셔츠 도매업 남녀용 겉옷 및 셔츠 도매업.1   기타주점업 기타주점업.1 일반 교과 학원 일반 교과 학원.1  \
# 0              사업체수              종사자수    사업체수    종사자수     사업체수       종사자수
# 1            13,388            51,116  13,339  31,371   11,911     50,773
# 2               400               962     537   1,413      110        382
# 3                 2                18      74     177        9         34
# 4                 2                 3       3       8        -          -
# ..              ...               ...     ...     ...      ...        ...
# 445              10                86      57     103       66        199
# 446              10               788      21      39       35         90
# 447               3                 6      47      98       31         67
# 448               4                17      95     268       24         42
# 449               6               126     122     294       39        136
#
#     한식 육류요리 전문점 한식 육류요리 전문점.1
# 0          사업체수          종사자수
# 1        11,109        44,653
# 2           437         1,982
# 3            45           220
# 4             7            33
# ..          ...           ...
# 445          44           164
# 446          24           101
# 447          34            98
# 448          69           245
# 449          70           224
#
# [450 rows x 22 columns]

# %%
# 데이터 프레임의 Shape을 확인합니다.
seoul_business.shape
# Out:
# (450, 22)

# %% [markdown]
# ---

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'seoul_moving' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보겠습니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   자치구                450 non-null    object
#  1   동                  450 non-null    object
#  2   택시운송업              450 non-null    object
#  3   택시운송업.1            450 non-null    object
#  4   한식 일반 음식점업         450 non-null    object
#  5   한식 일반 음식점업.1       450 non-null    object
#  6   용달 화물자동차 운송업       450 non-null    object
#  7   용달 화물자동차 운송업.1     450 non-null    object
#  8   부동산 중개 및 대리업       450 non-null    object
#  9   부동산 중개 및 대리업.1     450 non-null    object
#  10  두발미용업              450 non-null    object
#  11  두발미용업.1            450 non-null    object
#  12  커피전문점              450 non-null    object
#  13  커피전문점.1            450 non-null    object
#  14  남녀용 겉옷 및 셔츠 도매업    450 non-null    object
#  15  남녀용 겉옷 및 셔츠 도매업.1  450 non-null    object
#  16  기타주점업              450 non-null    object
#  17  기타주점업.1            450 non-null    object
#  18  일반 교과 학원           450 non-null    object
#  19  일반 교과 학원.1         450 non-null    object
#  20  한식 육류요리 전문점        450 non-null    object
#  21  한식 육류요리 전문점.1      450 non-null    object
# dtypes: object(22)
# memory usage: 77.5+ KB

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.describe()
# Out:
#         자치구    동 택시운송업 택시운송업.1 한식 일반 음식점업 한식 일반 음식점업.1 용달 화물자동차 운송업  \
# count   450  450   450     450        450          450          450
# unique   27  425   225     279        175          304          176
# top     송파구   소계    11      11         24           85           27
# freq     28   25     7       7         11            6            8
#
#        용달 화물자동차 운송업.1 부동산 중개 및 대리업 부동산 중개 및 대리업.1  ... 커피전문점 커피전문점.1  \
# count             450          450            450  ...   450     450
# unique            179          141            204  ...   130     238
# top                56           40             64  ...    13      16
# freq                9           11              9  ...    18       8
#
#        남녀용 겉옷 및 셔츠 도매업 남녀용 겉옷 및 셔츠 도매업.1 기타주점업 기타주점업.1 일반 교과 학원 일반 교과 학원.1  \
# count              450               450   450     450      450        450
# unique              68               146   126     188      112        221
# top                  1                 -    18      20        4          -
# freq                82                82    14      10       15         10
#
#        한식 육류요리 전문점 한식 육류요리 전문점.1
# count          450           450
# unique         106           229
# top             17            45
# freq            16             9
#
# [4 rows x 22 columns]

# %% [markdown]
# #### [실습문제3] 데이터 확인 및 처리
#
# * 데이터를 보았을때, 어느 데이터를 가져와야 할지 생각 해 봅시다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.head(6)
# Out:
#    자치구    동   택시운송업 택시운송업.1 한식 일반 음식점업 한식 일반 음식점업.1 용달 화물자동차 운송업  \
# 0  자치구    동    사업체수    종사자수       사업체수         종사자수         사업체수
# 1   합계   합계  47,176  76,701     29,225      100,183       28,494
# 2  종로구   소계     215     215      1,548        5,912          618
# 3  종로구  사직동       7       7        230          982           12
# 4  종로구  삼청동       5       5         42          145            4
# 5  종로구  부암동      22      22         26          100            9
#
#   용달 화물자동차 운송업.1 부동산 중개 및 대리업 부동산 중개 및 대리업.1  ...   커피전문점 커피전문점.1  \
# 0           종사자수         사업체수           종사자수  ...    사업체수    종사자수
# 1         29,356       24,013         42,636  ...  16,255  57,322
# 2            646          549            889  ...     948   3,613
# 3             12           57             96  ...     124     525
# 4              4            9             10  ...      66     243
# 5              9           17             26  ...      24      62
#
#   남녀용 겉옷 및 셔츠 도매업 남녀용 겉옷 및 셔츠 도매업.1   기타주점업 기타주점업.1 일반 교과 학원 일반 교과 학원.1  \
# 0            사업체수              종사자수    사업체수    종사자수     사업체수       종사자수
# 1          13,388            51,116  13,339  31,371   11,911     50,773
# 2             400               962     537   1,413      110        382
# 3               2                18      74     177        9         34
# 4               2                 3       3       8        -          -
# 5               3                 6       7      23       16         59
#
#   한식 육류요리 전문점 한식 육류요리 전문점.1
# 0        사업체수          종사자수
# 1      11,109        44,653
# 2         437         1,982
# 3          45           220
# 4           7            33
# 5           3            15
#
# [6 rows x 22 columns]

# %%
# temp = seoul_business.iloc[:,[0,1,3,5,7,9,11,13,15,17]]
temp = seoul_business

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
temp = temp.loc[temp['동'] == '소계']
temp.reset_index(drop=True, inplace=True)
temp.drop(labels='동', axis=1, inplace=True)
temp
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9456\2118322773.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp.drop(labels='동', axis=1, inplace=True)
#      자치구  택시운송업 택시운송업.1 한식 일반 음식점업 한식 일반 음식점업.1 용달 화물자동차 운송업 용달 화물자동차 운송업.1  \
# 0    종로구    215     215      1,548        5,912          618            646
# 1     중구    230     235      1,588        6,414          300            333
# 2    용산구    416     523        857        2,987          455            466
# 3    성동구  1,200   2,527        956        2,785        1,072          1,161
# 4    광진구  1,119   1,744        963        2,861          968            985
# 5   동대문구  1,546   2,093      1,236        3,566        1,431          1,456
# 6    중랑구  3,634   6,262        991        2,479        1,804          1,877
# 7    성북구  1,835   2,643        973        2,822        1,312          1,335
# 8    강북구  1,713   2,589        965        2,663        1,024          1,030
# 9    도봉구  2,993   5,783        672        2,009        1,571          1,574
# 10   노원구  4,114   6,074        866        2,650        1,730          1,736
# 11   은평구  3,108   4,430        881        2,585        1,340          1,349
# 12  서대문구  1,747   2,677        863        2,694          802            808
# 13   마포구  1,165   1,838      1,411        4,705          770            829
# 14   양천구  2,735   4,942        831        2,800        1,286          1,293
# 15   강서구  3,735   6,922      1,325        4,584        1,799          1,862
# 16   구로구  2,757   3,817      1,048        3,215        1,318          1,351
# 17   금천구  1,100   2,598        867        2,619          935            997
# 18  영등포구  1,349   2,397      1,738        6,476        1,281          1,429
# 19   동작구  1,033   1,115        765        2,322          830            844
# 20   관악구  1,286   2,027      1,226        3,689        1,579          1,600
# 21   서초구    417     903      1,564        6,712          386            411
# 22   강남구  1,796   2,517      2,415       11,486          445            487
# 23   송파구  2,638   4,850      1,575        5,760        1,910          1,931
# 24   강동구  3,295   4,980      1,101        3,388        1,528          1,566
#
#    부동산 중개 및 대리업 부동산 중개 및 대리업.1  두발미용업  ...  커피전문점 커피전문점.1 남녀용 겉옷 및 셔츠 도매업  \
# 0           549            889    261  ...    948   3,613             400
# 1           576          1,152    339  ...    869   3,542          10,810
# 2           791          1,214    366  ...    634   2,076              54
# 3           801          1,453    489  ...    547   1,859             149
# 4           871          1,313    746  ...    590   1,887              89
# 5           842          1,208    611  ...    494   1,472             211
# 6           738          1,104    790  ...    381   1,037              63
# 7           846          1,175    739  ...    457   1,384              85
# 8           589            867    673  ...    358   1,095              40
# 9           515            794    600  ...    288     837              22
# 10          714          1,053    782  ...    535   1,748              30
# 11        1,134          1,614    947  ...    457   1,296              26
# 12          667            956    598  ...    370   1,323              22
# 13        1,149          1,903    896  ...  1,369   4,475              96
# 14          922          1,364    838  ...    402   1,375              25
# 15        1,311          2,352  1,015  ...    690   2,530              78
# 16          789          1,213    729  ...    421   1,384             114
# 17          671          1,381    488  ...    383   1,215             200
# 18          986          1,566    673  ...    838   3,295              76
# 19          883          1,483    651  ...    486   1,628              20
# 20        1,010          2,136    895  ...    581   2,049              31
# 21        1,457          2,758    676  ...  1,012   3,897             157
# 22        2,337          6,508  1,241  ...  1,624   7,273             384
# 23        1,677          3,190  1,137  ...    975   3,372             147
# 24        1,188          1,990    900  ...    546   1,660              59
#
#    남녀용 겉옷 및 셔츠 도매업.1  기타주점업 기타주점업.1 일반 교과 학원 일반 교과 학원.1 한식 육류요리 전문점  \
# 0                962    537   1,413      110        382         437
# 1             24,248    381     982       57        175         443
# 2                317    487   1,332      104        573         300
# 3              1,572    285     621      258      1,494         400
# 4                687    633   1,577      413      1,646         467
# 5                976    499   1,082      302        984         442
# 6                284    535   1,000      288      1,045         499
# 7                454    512   1,030      464      1,755         365
# 8                 94    580   1,275      220        740         362
# 9                 43    258     477      351      1,162         302
# 10               123    355     844      735      3,281         428
# 11                74    484     925      551      1,793         476
# 12                68    497   1,127      361      1,268         311
# 13             1,209  1,011   2,559      469      1,855         701
# 14                52    415     851    1,284      5,804         281
# 15               700    794   1,709      672      2,347         581
# 16               923    576   1,165      336      1,111         428
# 17             2,575    391     685      153        487         300
# 18             1,220    636   1,489      288      1,082         494
# 19               199    439     955      407      1,463         331
# 20               190    658   1,672      354      1,230         422
# 21             1,563    446   1,255      812      3,812         445
# 22             8,320    713   2,528    1,426      9,020         827
# 23             2,830    628   1,469      876      4,160         639
# 24             1,433    589   1,349      620      2,104         428
#
#    한식 육류요리 전문점.1
# 0          1,982
# 1          2,121
# 2          1,184
# 3          1,545
# 4          1,678
# 5          1,509
# 6          1,504
# 7          1,334
# 8          1,176
# 9            943
# 10         1,557
# 11         1,639
# 12         1,088
# 13         2,928
# 14         1,111
# 15         2,274
# 16         1,496
# 17         1,042
# 18         2,151
# 19         1,177
# 20         1,628
# 21         2,338
# 22         5,008
# 23         2,781
# 24         1,459
#
# [25 rows x 21 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 해당 데이터프레임을 'df_seoul_business.csv' 파일로 저장하세요.

temp.to_csv('df_seoul_business.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화 한글폰트 설정
# 맑은 고딕

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# scipy
import scipy.stats as spst

# %% [markdown]
# #### [실습문제4] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 
# 2.
# 3.

# %% [markdown]
# ---
