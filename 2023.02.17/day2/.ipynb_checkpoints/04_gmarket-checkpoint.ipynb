# %% [markdown]
# ### Gmarket
# - 베스트 상품 200개 데이터 수집
# - 상품의 이미지 200개 다운로드

# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup

# %% [markdown]
# #### 1. URL 찾기

# %%
url = 'https://corners.gmarket.co.kr/bestsellers'

# %% [markdown]
# #### 2. request > response : str(html)

# %%
response = requests.get(url) 
response
# Out:
# <Response [200]>

# %% [markdown]
# #### 3. bs > DataFrame

# %%
dom = BeautifulSoup(response.text, 'html.parser')

# %%
dom
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <title>G마켓 - G마켓 베스트</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="text/css" http-equiv="content-style-type"/>
# <meta content="text/javascript" http-equiv="content-script-type"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="width=980" id="viewport" name="viewport"/>
# <meta content="all" name="ROBOTS"/>
# <meta content="인터넷쇼핑,오픈마켓,패션/뷰티,디지털,식품/유아,스포츠/자동차,생활용품,도서/DVD,여행/항공권,e쿠폰/티켓,만화/게임,공동구매,경매,중고,글로벌쇼핑,브랜드샵,베스트셀러,방문쇼핑몰,G스탬프,할인쿠폰,동영상,이벤트 등 G마켓" name="description"/>
# <meta content="베스트100,베스트셀러,경매,할인쿠폰,베스트셀러,공동구매,컴퓨터/핸드폰,에어컨/TV/디카,MP3/게임,패션/명품/브랜드,여성의류/속옷,남성의류/정장/빅사이즈,분유/기저귀/식품/생리대/임부복,유아동/장난감,쌀/과일/한우/생선,건강식품/음료,화장품/자동차,스포츠/다이어트,골프/등산/스키/낚시,운동화,네비게이션,리빙/침구/인테리어,애완/성인/공구,꽃배달,도서/여행/항공권,만화" name="keywords"/>
# <meta content="(주)이베이코리아" name="author"/>
# <meta content="Copyright © eBay Korea Co., Ltd. All Rights Reserved." name="copyright"/>
# <meta content="gmarket@corp.gmarket.co.kr" name="reply-to"/>
# <meta content="http://www.gmarket.co.kr/?jaehuid=200004313" name="msapplication-starturl"/>
# <meta content="name=G마켓 베스트; action-uri=http://promotion.gmarket.co.kr/bestseller/BestSeller.asp?jaehuid=200004313; icon-uri=//image.gmarket.co.kr/favicon/bestseller.ico" name="msapplication-task"/>
# <meta content="name=이벤트/쿠폰; action-uri=http://promotion.gmarket.co.kr/eventzone/Info.asp?jaehuid=200004313; icon-uri=//image.gmarket.co.kr/favicon/eventcoupon.ico" name="msapplication-task"/>
# <meta content="name=플러스존; action-uri=http://pluszone.gmarket.co.kr/default.asp?jaehuid=200004313; icon-uri=//image.gmarket.co.kr/favicon/pluszone.ico" name="msapplication-task"/>
# <meta content="name=최근구매내역; action-uri=http://www.gmarket.co.kr/challenge/neo_my_gd/order_contract_list.asp?jaehuid=200004313; icon-uri=//image.gmarket.co.kr/favicon/orderlist.ico" name="msapplication-task"/>
# <meta content="name=나의 장바구니; action-uri=http://www.gmarket.co.kr/payment/Basket.asp?jaehuid=200004313; icon-uri=//image.gmarket.co.kr/favicon/basket.ico" name="msapplication-task"/>
# <link href="//image.gmarket.co.kr/favicon/gmarket.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//script.gmarket.co.kr/pc/css/ko/common.css" rel="stylesheet" type="text/css"/>
# <!-- 미사용 -->
# <!-- gbest.css 변경 -->
# <link href="//script.gmarket.co.kr/pc/css/ko/corner/gbest.css" rel="stylesheet" type="text/css"/>
# <script src="//www.gmarket.co.kr/challenge/neo_include/favicon.js" type="text/javascript"></script>
# <script type="text/javascript">
# 		document.domain = "gmarket.co.kr";
# 	</script>
# <script src="//script.gmarket.co.kr/_Net/js/jquery-1.8.3.min.js" type="text/javascript"></script>
# <script src="//script.gmarket.co.kr/_Net/js/corners/jquery.lazyload.customized.js" type="text/javascript"></script>
# <script src="/Scripts/Gmarket.Diagnostics.ScriptError.js" type="text/javascript"></script>
# <script src="/Scripts/Gmarket.Services.GmarketService.js" type="text/javascript"></script>
# <script type="text/javascript">
# 		var _ContentUrls = ["//script.gmarket.co.kr/_Net/css/myg/","//image.gmarket.co.kr/_Net/","//script.gmarket.co.kr/_Net/","//script.gmarket.co.kr/_Net/css/myg/ssl/","//sslimage.gmarket.co.kr/_Net/","//script.gmarket.co.kr/_Net/","http://myg.gmarket.co.kr/","https://myg.gmarket.co.kr/","http://member.gmarket.co.kr/","https://member.gmarket.co.kr/","http://gbank.gmarket.co.kr/","https://gbank.gmarket.co.kr/","http://claim.gmarket.co.kr/","https://claim.gmarket.co.kr/","http://escrow.gmarket.co.kr/","https://sslescrow.gmarket.co.kr/","http://diary.gmarket.co.kr/","http://event.gmarket.co.kr/","http://sns.gmarket.co.kr/","http://www.gmarket.co.kr/","https://www.gmarket.co.kr/","http://item.gmarket.co.kr/","http://shop.gmarket.co.kr/","http://member2.gmarket.co.kr/","https://sslmember2.gmarket.co.kr/","http://promotion.gmarket.co.kr/","http://diary2.gmarket.co.kr/","http://eventnet.gmarket.co.kr/","http://ebay.gmarket.co.kr/","http://www.g9.co.kr/","http://signin.gmarket.co.kr/","https://signin.gmarket.co.kr/","/","/","/","/","/","/","/","/","/","/","/","/","/","/","https://www.g9.co.kr/","http://diary2.gmarket.co.kr/","/","/","/",];
# ;
# 		var headerKey = "";
#     </script>
# <script src="//script.gmarket.co.kr/_Net/js/gmkt.js?dummy=2012091327262" type="text/javascript"></script>
# <script src="//script.gmarket.co.kr/_Net/js/dimmed.js" type="text/javascript"></script>
# <script src="//script.gmarket.co.kr/_Net/js/CommonHeader.js" type="text/javascript"></script>
# <script src="//script.gmarket.co.kr/_Net/js/core/CommonTopCommonUTF8.js" type="text/javascript"></script>
# </head>
# <body>
# <!-- skipnavi-->
# <div id="skip-navigation">
# <strong class="for-a11y">스킵 네비게이션</strong>
# <ul>
# <li><a href="#skip-navigation-search">검색창 바로가기</a></li>
# <li><a href="#skip-navigation-category-all">전체카테고리 바로가기</a></li>
# <li><a href="#wrap">본문 바로가기</a></li>
# </ul>
# </div>
# <!-- //skipnavi -->
# <!-- header -->
# <link href="//script.gmarket.co.kr/pc/css/common/kr/ui/desktop_layout.css" rel="stylesheet"/>
# <script src="//script.gmarket.co.kr//fnp/desktop-layout.js"></script>
# <!-- // header -->
# <div id="header">
# <script type="text/javascript">
# 		DesktopLayout.render([{
# 			name: "Header",
# 			params: {"type":"sub","user":{"name":"","grade":"Unknown"},"isAdult":false},
# 			container: document.getElementById("header")
# 		}]);
# 	</script>
# </div>
# <div id="container" role="main">
# <a name="top"></a>
# <div id="gBestWrap">
# <div class="gbest-top">
# <h2><a href="/BestSellers">G마켓 BEST</a></h2>
# <div class="box__layer-info box__info-gbest">
# <button aria-expanded="false" class="button__questicon" type="button"><span class="for-a11y">G마켓베스트란</span></button>
# <div class="box__layer-info--inner">
# <strong class="for-a11y">안내글</strong>
# <div class="box__layer-cont">
# <strong>G마켓베스트란?</strong>
# <span>상품의 판매실적과 상품가격대별 가중치를 주된 기준으로 하여 G마켓이 선정한 상품입니다.</span>
# </div>
# <button class="button__closed" type="button"><span class="for-a11y">닫기</span></button>
# </div>
# </div>
# <ul class="tab" data-mode="aria1.2" role="tablist">
# <li id="groupMode" role="none"><a aria-controls="categoryTabG" aria-selected="false" href="/BestSellers" onclick="pdsClickLog('200000683', 'Utility', {'viewType': 1});" role="tab">그룹별</a></li>
# <li id="categoryMode" role="none">
# <a aria-controls="categoryTabC" aria-selected="false" href="/BestSellers?viewType=C" onclick="pdsClickLog('200000683', 'Utility', {'viewType': 2});" role="tab">카테고리별</a>
# <div class="box__layer-info box__info-category">
# <button aria-expanded="false" class="button__questicon" type="button"><span class="for-a11y">그룹별베스트, 카테고리별베스트란?</span></button>
# <div class="box__layer-info--inner">
# <strong class="for-a11y">안내글</strong>
# <div class="box__layer-cont">
# <strong>그룹별베스트, 카테고리별베스트란?</strong>
# <span>상품의 판매실적을 기반으로 상품가격대별<br/>가중치와 부가서비스구매실적을 반영하여 G마켓이 선정한 상품입니다.</span>
# </div>
# <button class="button__closed" type="button"><span class="for-a11y">닫기</span></button>
# </div>
# </div>
# </li>
# </ul>
# <div class="gbest-cate">
# <ul aria-label="그룹별 리스트" class="by-group" id="categoryTabG" style="display:">
# <li class="groupA on"><a href="/Bestsellers" role="link">ALL</a></li>
# <li class="group1"><a href="/Bestsellers?viewType=G&amp;groupCode=G01" onclick="pdsClickLog('200000676', 'Item', {'ASN': 1, 'groupCode': 'G01'});" role="link">패션의류</a></li>
# <li class="group2"><a href="/Bestsellers?viewType=G&amp;groupCode=G02" onclick="pdsClickLog('200000676', 'Item', {'ASN': 2, 'groupCode': 'G02'});" role="link">신발/잡화</a></li>
# <li class="group3"><a href="/Bestsellers?viewType=G&amp;groupCode=G03" onclick="pdsClickLog('200000676', 'Item', {'ASN': 3, 'groupCode': 'G03'});" role="link">화장품/헤어</a></li>
# <li class="group4"><a href="/Bestsellers?viewType=G&amp;groupCode=G04" onclick="pdsClickLog('200000676', 'Item', {'ASN': 4, 'groupCode': 'G04'});" role="link">유아동/출산</a></li>
# <li class="group5"><a href="/Bestsellers?viewType=G&amp;groupCode=G07" onclick="pdsClickLog('200000676', 'Item', {'ASN': 5, 'groupCode': 'G07'});" role="link">식품</a></li>
# <li class="group6"><a href="/Bestsellers?viewType=G&amp;groupCode=G08" onclick="pdsClickLog('200000676', 'Item', {'ASN': 6, 'groupCode': 'G08'});" role="link">생활/주방/건강</a></li>
# <li class="group7"><a href="/Bestsellers?viewType=G&amp;groupCode=G09" onclick="pdsClickLog('200000676', 'Item', {'ASN': 7, 'groupCode': 'G09'});" role="link">가구/침구</a></li>
# <li class="group8"><a href="/Bestsellers?viewType=G&amp;groupCode=G05" onclick="pdsClickLog('200000676', 'Item', {'ASN': 8, 'groupCode': 'G05'});" role="link">스포츠/자동차</a></li>
# <li class="group9"><a href="/Bestsellers?viewType=G&amp;groupCode=G06" onclick="pdsClickLog('200000676', 'Item', {'ASN': 9, 'groupCode': 'G06'});" role="link">컴퓨터/전자</a></li>
# <li class="group10"><a href="/Bestsellers?viewType=G&amp;groupCode=G10" onclick="pdsClickLog('200000676', 'Item', {'ASN': 10, 'groupCode': 'G10'});" role="link">도서/음반</a></li>
# <li class="group11"><a href="/Bestsellers?viewType=G&amp;groupCode=G11" onclick="pdsClickLog('200000676', 'Item', {'ASN': 11, 'groupCode': 'G11'});" role="link">여행</a></li>
# <li class="group12"><a href="/Bestsellers?viewType=G&amp;groupCode=G12" onclick="pdsClickLog('200000676', 'Item', {'ASN': 12, 'groupCode': 'G12'});" role="link">e쿠폰/티켓</a></li>
# </ul>
# <div aria-label="카테고리별 리스트" class="by-cate" id="categoryTabC" style="display:none;">
# <div class="cate1">
# <p class="top">브랜드패션</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000103" onclick="pdsClickLog('200000685', 'Item', {'ASN': 1, 'largeCategoryCode': '100000103'});">브랜드 여성의류</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000104" onclick="pdsClickLog('200000685', 'Item', {'ASN': 2, 'largeCategoryCode': '100000104'});">브랜드 남성의류</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000105" onclick="pdsClickLog('200000685', 'Item', {'ASN': 3, 'largeCategoryCode': '100000105'});">브랜드 진/캐쥬얼</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000106" onclick="pdsClickLog('200000685', 'Item', {'ASN': 4, 'largeCategoryCode': '100000106'});">브랜드 신발/가방</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000107" onclick="pdsClickLog('200000685', 'Item', {'ASN': 5, 'largeCategoryCode': '100000107'});">브랜드 쥬얼리/시계</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000096" onclick="pdsClickLog('200000685', 'Item', {'ASN': 6, 'largeCategoryCode': '100000096'});">수입 명품</a></li>
# </ul>
# <p>패션의류</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000003" onclick="pdsClickLog('200000685', 'Item', {'ASN': 7, 'largeCategoryCode': '100000003'});">여성의류</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000046" onclick="pdsClickLog('200000685', 'Item', {'ASN': 8, 'largeCategoryCode': '100000046'});">남성의류</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000070" onclick="pdsClickLog('200000685', 'Item', {'ASN': 9, 'largeCategoryCode': '100000070'});">언더웨어</a></li>
# </ul>
# <p>패션잡화/뷰티</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000049" onclick="pdsClickLog('200000685', 'Item', {'ASN': 10, 'largeCategoryCode': '100000049'});">신발</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000064" onclick="pdsClickLog('200000685', 'Item', {'ASN': 11, 'largeCategoryCode': '100000064'});">가방/잡화</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000027" onclick="pdsClickLog('200000685', 'Item', {'ASN': 12, 'largeCategoryCode': '100000027'});">쥬얼리/시계</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000005" onclick="pdsClickLog('200000685', 'Item', {'ASN': 13, 'largeCategoryCode': '100000005'});">화장품/향수</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000071" onclick="pdsClickLog('200000685', 'Item', {'ASN': 14, 'largeCategoryCode': '100000071'});">바디/헤어</a></li>
# </ul>
# </div>
# <div class="cate2">
# <p class="top">유아동</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000006" onclick="pdsClickLog('200000685', 'Item', {'ASN': 15, 'largeCategoryCode': '100000006'});">출산/육아</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000042" onclick="pdsClickLog('200000685', 'Item', {'ASN': 16, 'largeCategoryCode': '100000042'});">장난감/완구</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000035" onclick="pdsClickLog('200000685', 'Item', {'ASN': 17, 'largeCategoryCode': '100000035'});">유아동의류</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000095" onclick="pdsClickLog('200000685', 'Item', {'ASN': 18, 'largeCategoryCode': '100000095'});">유아동신발/잡화</a></li>
# </ul>
# <p>식품</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000020" onclick="pdsClickLog('200000685', 'Item', {'ASN': 19, 'largeCategoryCode': '100000020'});">신선식품</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000036" onclick="pdsClickLog('200000685', 'Item', {'ASN': 20, 'largeCategoryCode': '100000036'});">가공식품</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000068" onclick="pdsClickLog('200000685', 'Item', {'ASN': 21, 'largeCategoryCode': '100000068'});">건강식품</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000094" onclick="pdsClickLog('200000685', 'Item', {'ASN': 22, 'largeCategoryCode': '100000094'});">커피/음료</a></li>
# </ul>
# </div>
# <div class="cate3">
# <p class="top">생필품/건강/렌탈</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000074" onclick="pdsClickLog('200000685', 'Item', {'ASN': 23, 'largeCategoryCode': '100000074'});">생필품</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000083" onclick="pdsClickLog('200000685', 'Item', {'ASN': 24, 'largeCategoryCode': '100000083'});">건강/의료용품</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000112" onclick="pdsClickLog('200000685', 'Item', {'ASN': 25, 'largeCategoryCode': '100000112'});">렌탈 서비스</a></li>
# </ul>
# <p>홈데코</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000031" onclick="pdsClickLog('200000685', 'Item', {'ASN': 26, 'largeCategoryCode': '100000031'});">가구/DIY</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000039" onclick="pdsClickLog('200000685', 'Item', {'ASN': 27, 'largeCategoryCode': '100000039'});">침구/커튼</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000093" onclick="pdsClickLog('200000685', 'Item', {'ASN': 28, 'largeCategoryCode': '100000093'});">조명/인테리어</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000014" onclick="pdsClickLog('200000685', 'Item', {'ASN': 29, 'largeCategoryCode': '100000014'});">생활용품</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000085" onclick="pdsClickLog('200000685', 'Item', {'ASN': 30, 'largeCategoryCode': '100000085'});">주방용품</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000041" onclick="pdsClickLog('200000685', 'Item', {'ASN': 31, 'largeCategoryCode': '100000041'});">꽃/이벤트용품</a></li>
# </ul>
# </div>
# <div class="cate4">
# <p class="top">자동차/공구</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000030" onclick="pdsClickLog('200000685', 'Item', {'ASN': 32, 'largeCategoryCode': '100000030'});">자동차용품</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000076" onclick="pdsClickLog('200000685', 'Item', {'ASN': 33, 'largeCategoryCode': '100000076'});">공구/안전/산업용품</a></li>
# </ul>
# <p>문구/취미/반려</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000045" onclick="pdsClickLog('200000685', 'Item', {'ASN': 34, 'largeCategoryCode': '100000045'});">문구/사무용품</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000091" onclick="pdsClickLog('200000685', 'Item', {'ASN': 35, 'largeCategoryCode': '100000091'});">악기/취미</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000038" onclick="pdsClickLog('200000685', 'Item', {'ASN': 36, 'largeCategoryCode': '100000038'});">반려동물용품</a></li>
# </ul>
# <p>스포츠</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000043" onclick="pdsClickLog('200000685', 'Item', {'ASN': 37, 'largeCategoryCode': '100000043'});">스포츠의류/운동화</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000037" onclick="pdsClickLog('200000685', 'Item', {'ASN': 38, 'largeCategoryCode': '100000037'});">휘트니스/수영</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000098" onclick="pdsClickLog('200000685', 'Item', {'ASN': 39, 'largeCategoryCode': '100000098'});">구기/라켓</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000058" onclick="pdsClickLog('200000685', 'Item', {'ASN': 40, 'largeCategoryCode': '100000058'});">골프</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000097" onclick="pdsClickLog('200000685', 'Item', {'ASN': 41, 'largeCategoryCode': '100000097'});">자전거/보드/기타레저</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000017" onclick="pdsClickLog('200000685', 'Item', {'ASN': 42, 'largeCategoryCode': '100000017'});">캠핑/낚시</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000099" onclick="pdsClickLog('200000685', 'Item', {'ASN': 43, 'largeCategoryCode': '100000099'});">등산/아웃도어</a></li>
# </ul>
# </div>
# <div class="cate5">
# <p class="top">컴퓨터</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000002" onclick="pdsClickLog('200000685', 'Item', {'ASN': 44, 'largeCategoryCode': '100000002'});">노트북/PC</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000082" onclick="pdsClickLog('200000685', 'Item', {'ASN': 45, 'largeCategoryCode': '100000082'});">모니터/프린터</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000055" onclick="pdsClickLog('200000685', 'Item', {'ASN': 46, 'largeCategoryCode': '100000055'});">PC주변기기</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000075" onclick="pdsClickLog('200000685', 'Item', {'ASN': 47, 'largeCategoryCode': '100000075'});">저장장치</a></li>
# </ul>
# <p>디지털</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000056" onclick="pdsClickLog('200000685', 'Item', {'ASN': 48, 'largeCategoryCode': '100000056'});">모바일/태블릿</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000033" onclick="pdsClickLog('200000685', 'Item', {'ASN': 49, 'largeCategoryCode': '100000033'});">카메라</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000111" onclick="pdsClickLog('200000685', 'Item', {'ASN': 50, 'largeCategoryCode': '100000111'});">게임</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000102" onclick="pdsClickLog('200000685', 'Item', {'ASN': 51, 'largeCategoryCode': '100000102'});">음향기기</a></li>
# </ul>
# <p>가전</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000032" onclick="pdsClickLog('200000685', 'Item', {'ASN': 52, 'largeCategoryCode': '100000032'});">영상가전</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000008" onclick="pdsClickLog('200000685', 'Item', {'ASN': 53, 'largeCategoryCode': '100000008'});">주방가전</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000077" onclick="pdsClickLog('200000685', 'Item', {'ASN': 54, 'largeCategoryCode': '100000077'});">계절가전</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000092" onclick="pdsClickLog('200000685', 'Item', {'ASN': 55, 'largeCategoryCode': '100000092'});">생활/미용가전</a></li>
# </ul>
# </div>
# <div class="cate6">
# <p class="top">여행/도서/티켓/e쿠폰</p>
# <ul>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000013" onclick="pdsClickLog('200000685', 'Item', {'ASN': 56, 'largeCategoryCode': '100000013'});">여행/항공권</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000028" onclick="pdsClickLog('200000685', 'Item', {'ASN': 57, 'largeCategoryCode': '100000028'});">도서음반/e교육</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000048" onclick="pdsClickLog('200000685', 'Item', {'ASN': 58, 'largeCategoryCode': '100000048'});">e쿠폰</a></li>
# <li><a href="/BestSellers?viewType=C&amp;largeCategoryCode=100000084" onclick="pdsClickLog('200000685', 'Item', {'ASN': 59, 'largeCategoryCode': '100000084'});">상품권</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div>
# <div aria-label="베스트 상품 리스트" class="best-list" role="region">
# <ul>
# <li class="first" id="itemidx1">
# <p class="no1" id="no1">1</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2628342593&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2628342593'}); setStorageItem('1','2628342593','200');"><img alt="[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음" class="lazy" data-original="//gdimg.gmarket.co.kr/2628342593/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/allmaeil"><span class="view">판매자 다른상품 보기</span>매일유업공식판매업체</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2628342593&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2628342593'}); setStorageItem('1','2628342593','200');">[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>33,800원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>23,700원</span></strong>
# <span><span class="sale"></span><em>29%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx2">
# <p class="no2" id="no2">2</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=1998535842&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 2, 'goodsCode': '1998535842'}); setStorageItem('2','1998535842','200');"><img alt="[피셔프라이스]피셔프라이스 러닝 푸드트럭" class="lazy" data-original="//gdimg.gmarket.co.kr/1998535842/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/mattelshop"><span class="view">판매자 다른상품 보기</span>손오공마텔공식인증점</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=1998535842&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 2, 'goodsCode': '1998535842'}); setStorageItem('2','1998535842','200');">[피셔프라이스]피셔프라이스 러닝 푸드트럭</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>210,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>99,000원</span></strong>
# <span><span class="sale"></span><em>52%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx3">
# <p class="no3" id="no3">3</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2772877848&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 3, 'goodsCode': '2772877848'}); setStorageItem('3','2772877848','200');"><img alt="[나이키키즈](대구신세계)[나이키키즈] (105~170) 조던 썸머 상/하의세트 세일가" class="lazy" data-original="//gdimg.gmarket.co.kr/2772877848/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/shinsegae9"><span class="view">판매자 다른상품 보기</span>신세계백화점</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2772877848&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 3, 'goodsCode': '2772877848'}); setStorageItem('3','2772877848','200');">[나이키키즈](대구신세계)[나이키키즈] (105~170) 조던 썸머 상/하의세트 세일가</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>58,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>45,820원</span></strong>
# <span><span class="sale"></span><em>21%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx4">
# <p class="no4" id="no4">4</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2767818438&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 4, 'goodsCode': '2767818438'}); setStorageItem('4','2767818438','200');"><img alt="(지오지아)사계절 테이퍼드/와이드핏 슬랙스  치노팬츠 10종 택1" class="lazy" data-original="//gdimg.gmarket.co.kr/2767818438/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/lottedep"><span class="view">판매자 다른상품 보기</span>롯데 백화점</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2767818438&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 4, 'goodsCode': '2767818438'}); setStorageItem('4','2767818438','200');">(지오지아)사계절 테이퍼드/와이드핏 슬랙스  치노팬츠 10종 택1</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>32,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>24,640원</span></strong>
# <span><span class="sale"></span><em>23%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li class="first" id="itemidx5">
# <p class="no5" id="no5">5</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2780877061&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 5, 'goodsCode': '2780877061'}); setStorageItem('5','2780877061','200');"><img alt="[플랙]남성 데님 팬츠 6종 택1(PJTT5MLD731외5종)" class="lazy" data-original="//gdimg.gmarket.co.kr/2780877061/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/lottedep"><span class="view">판매자 다른상품 보기</span>롯데 백화점</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2780877061&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 5, 'goodsCode': '2780877061'}); setStorageItem('5','2780877061','200');">[플랙]남성 데님 팬츠 6종 택1(PJTT5MLD731외5종)</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>69,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>50,370원</span></strong>
# <span><span class="sale"></span><em>27%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx6">
# <p class="no6" id="no6">6</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2762345389&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 6, 'goodsCode': '2762345389'}); setStorageItem('6','2762345389','200');"><img alt="[맥도날드](선물하기 특가)(맥도날드) 디지털상품권 1만원권" class="lazy" data-original="//gdimg.gmarket.co.kr/2762345389/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/coopmktcom"><span class="view">판매자 다른상품 보기</span>쿠프마케팅</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2762345389&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 6, 'goodsCode': '2762345389'}); setStorageItem('6','2762345389','200');">[맥도날드](선물하기 특가)(맥도날드) 디지털상품권 1만원권</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>10,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>9,150원</span></strong>
# <span><span class="sale"></span><em>8%</em></span>
# </div>
# <div class="icon">
# </div>
# </div>
# </li>
# <li id="itemidx7">
# <p class="no7" id="no7">7</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=182821824&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 7, 'goodsCode': '182821824'}); setStorageItem('7','182821824','200');"><img alt="아동팬티 삼각 주니어 속옷 런닝 드로즈 남아 여아동" class="lazy" data-original="//gdimg.gmarket.co.kr/182821824/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/innerwear"><span class="view">판매자 다른상품 보기</span>캐릭토피아</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=182821824&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 7, 'goodsCode': '182821824'}); setStorageItem('7','182821824','200');">아동팬티 삼각 주니어 속옷 런닝 드로즈 남아 여아동</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>26,300원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>7,900원</span></strong>
# <span><span class="sale"></span><em>69%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx8">
# <p class="no8" id="no8">8</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=1977052165&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 8, 'goodsCode': '1977052165'}); setStorageItem('8','1977052165','200');"><img alt="[풀무원]생면식감 직화짜장 16개입(4입 4봉)" class="lazy" data-original="//gdimg.gmarket.co.kr/1977052165/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/ssgmall"><span class="view">판매자 다른상품 보기</span>신세계몰</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=1977052165&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 8, 'goodsCode': '1977052165'}); setStorageItem('8','1977052165','200');">[풀무원]생면식감 직화짜장 16개입(4입 4봉)</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>10,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>9,400원</span></strong>
# <span><span class="sale"></span><em>6%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li class="first" id="itemidx9">
# <p class="no9" id="no9">9</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2635078880&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 9, 'goodsCode': '2635078880'}); setStorageItem('9','2635078880','200');"><img alt="[일동후디스]일동후디스 하이뮨 프로틴 밸런스 6통+전용보틀+전용스푼 3개" class="lazy" data-original="//gdimg.gmarket.co.kr/2635078880/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/nsmalltv"><span class="view">판매자 다른상품 보기</span>NS홈쇼핑</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2635078880&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 9, 'goodsCode': '2635078880'}); setStorageItem('9','2635078880','200');">[일동후디스]일동후디스 하이뮨 프로틴 밸런스 6통+전용보틀+전용스푼 3개</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>144,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>118,080원</span></strong>
# <span><span class="sale"></span><em>18%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx10">
# <p class="no10" id="no10">10</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2347262038&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 10, 'goodsCode': '2347262038'}); setStorageItem('10','2347262038','200');"><img alt="[아이더](신세계강남점)봄 신학기 기능성 남여공용 바람막이 브레스트 / DMP21163(강남점 단독)" class="lazy" data-original="//gdimg.gmarket.co.kr/2347262038/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/shinsegae9"><span class="view">판매자 다른상품 보기</span>신세계백화점</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2347262038&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 10, 'goodsCode': '2347262038'}); setStorageItem('10','2347262038','200');">[아이더](신세계강남점)봄 신학기 기능성 남여공용 바람막이 브레스트 / DMP21163(강남점 단독)</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>65,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>52,490원</span></strong>
# <span><span class="sale"></span><em>19%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx11">
# <p class="no11" id="no11">11</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2090522905&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 11, 'goodsCode': '2090522905'}); setStorageItem('11','2090522905','200');"><img alt="[사조대림]사조해표 콩기름 1.8L x 3병" class="lazy" data-original="//gdimg.gmarket.co.kr/2090522905/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/kpsajo"><span class="view">판매자 다른상품 보기</span>사조대림스마일배송</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2090522905&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 11, 'goodsCode': '2090522905'}); setStorageItem('11','2090522905','200');">[사조대림]사조해표 콩기름 1.8L x 3병</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>25,400원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>22,360원</span></strong>
# <span><span class="sale"></span><em>11%</em></span>
# </div>
# <div class="icon">
# <img alt="스마일배송" src="//pics.gmarket.co.kr/pc/ko/corner/gbest/ic_smile_shipped.png"/>
# </div>
# </div>
# </li>
# <li id="itemidx12">
# <p class="no12" id="no12">12</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2779014323&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 12, 'goodsCode': '2779014323'}); setStorageItem('12','2779014323','200');"><img alt="[엔비에이](현대백화점)[NBA] 남여공용 맨투맨 후드티셔츠 후리스점퍼 5종택1 (N214TS292외 4종)" class="lazy" data-original="//gdimg.gmarket.co.kr/2779014323/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/hdepart01"><span class="view">판매자 다른상품 보기</span>현대백화점</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2779014323&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 12, 'goodsCode': '2779014323'}); setStorageItem('12','2779014323','200');">[엔비에이](현대백화점)[NBA] 남여공용 맨투맨 후드티셔츠 후리스점퍼 5종택1 (N214TS292외 4종)</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>29,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>25,230원</span></strong>
# <span><span class="sale"></span><em>13%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li class="first" id="itemidx13">
# <p class="no13" id="no13">13</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2246382810&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 13, 'goodsCode': '2246382810'}); setStorageItem('13','2246382810','200');"><img alt="[쉬크]쉬크 하이드로5 베이스 날14입+면도기" class="lazy" data-original="//gdimg.gmarket.co.kr/2246382810/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/kplgcare1"><span class="view">판매자 다른상품 보기</span>kp_lgcare</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2246382810&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 13, 'goodsCode': '2246382810'}); setStorageItem('13','2246382810','200');">[쉬크]쉬크 하이드로5 베이스 날14입+면도기</a>
# <div class="item_price">
# <div class="o-price"></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>23,700원</span></strong>
# </div>
# <div class="icon">
# <img alt="스마일배송" src="//pics.gmarket.co.kr/pc/ko/corner/gbest/ic_smile_shipped.png"/>
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx14">
# <p class="no14" id="no14">14</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=1655242371&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 14, 'goodsCode': '1655242371'}); setStorageItem('14','1655242371','200');"><img alt="[구글플레이]기프트코드 10만원 / 구글 기프트카드" class="lazy" data-original="//gdimg.gmarket.co.kr/1655242371/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/happymoney2012"><span class="view">판매자 다른상품 보기</span>(주)한국선불카드</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=1655242371&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 14, 'goodsCode': '1655242371'}); setStorageItem('14','1655242371','200');">[구글플레이]기프트코드 10만원 / 구글 기프트카드</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>100,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>95,000원</span></strong>
# <span><span class="sale"></span><em>5%</em></span>
# </div>
# <div class="icon">
# </div>
# </div>
# </li>
# <li id="itemidx15">
# <p class="no15" id="no15">15</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=
amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 20, 'goodsCode': '2793603131'}); setStorageItem('20','2793603131','200');"><img alt="[블루독]블루독 봄입고 인하 15%+15%추가쿠폰+무료배송" class="lazy" data-original="//gdimg.gmarket.co.kr/2793603131/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/thesymall"><span class="view">판매자 다른상품 보기</span>블루독패밀리</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2793603131&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 20, 'goodsCode': '2793603131'}); setStorageItem('20','2793603131','200');">[블루독]블루독 봄입고 인하 15%+15%추가쿠폰+무료배송</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>129,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>38,700원</span></strong>
# <span><span class="sale"></span><em>70%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li class="first" id="itemidx21">
# <p class="no21" id="no21">21</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2503772943&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 21, 'goodsCode': '2503772943'}); setStorageItem('21','2503772943','200');"><img alt="[압타밀]압타밀 프로푸트라 HMO 2단계 800g x 6통 세트" class="lazy" data-original="//gdimg.gmarket.co.kr/2503772943/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/7monday"><span class="view">판매자 다른상품 보기</span>7monday</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2503772943&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 21, 'goodsCode': '2503772943'}); setStorageItem('21','2503772943','200');">[압타밀]압타밀 프로푸트라 HMO 2단계 800g x 6통 세트</a>
# <div class="item_price">
# <div class="o-price"></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>199,000원</span></strong>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx22">
# <p class="no22" id="no22">22</p>
# <div class="thumb">
# ...
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>25,870원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>18,900원</span></strong>
# <span><span class="sale"></span><em>26%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li class="first" id="itemidx197">
# <p class="no197" id="no197">197</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2774807080&amp;ver=638122426476984340" onclick="pdsClickLog('200000680', 'Item', {'ASN': 197, 'goodsCode': '2774807080'}); setStorageItem('197','2774807080','200');"><img alt="[압타밀]압타밀 프로푸트라 1단계 800g 4통 세트 독일내수용 / 빠른배송 / 최신제품" class="lazy" data-original="//gdimg.gmarket.co.kr/2774807080/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/jhmglobal"><span class="view">판매자 다른상품 보기</span>JHMGlobal</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2774807080&amp;ver=638122426476984340" onclick="pdsClickLog('200000680', 'Item', {'ASN': 197, 'goodsCode': '2774807080'}); setStorageItem('197','2774807080','200');">[압타밀]압타밀 프로푸트라 1단계 800g 4통 세트 독일내수용 / 빠른배송 / 최신제품</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>149,800원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>143,060원</span></strong>
# <span><span class="sale"></span><em>4%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx198">
# <p class="no198" id="no198">198</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2762398385&amp;ver=638122426476984340" onclick="pdsClickLog('200000680', 'Item', {'ASN': 198, 'goodsCode': '2762398385'}); setStorageItem('198','2762398385','200');"><img alt="2세대 코코맘 이동식트롤리 기저귀정리함 3단 캡형" class="lazy" data-original="//gdimg.gmarket.co.kr/2762398385/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/plafarm"><span class="view">판매자 다른상품 보기</span>전원테크</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2762398385&amp;ver=638122426476984340" onclick="pdsClickLog('200000680', 'Item', {'ASN': 198, 'goodsCode': '2762398385'}); setStorageItem('198','2762398385','200');">2세대 코코맘 이동식트롤리 기저귀정리함 3단 캡형</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>51,900원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>44,900원</span></strong>
# <span><span class="sale"></span><em>13%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx199">
# <p class="no199" id="no199">199</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2793644100&amp;ver=638122426476984340" onclick="pdsClickLog('200000680', 'Item', {'ASN': 199, 'goodsCode': '2793644100'}); setStorageItem('199','2793644100','200');"><img alt="레인보우 중목 라인양말_10+10켤레 세트 (할인특가)" class="lazy" data-original="//gdimg.gmarket.co.kr/2793644100/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/falla"><span class="view">판매자 다른상품 보기</span>FALLA</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2793644100&amp;ver=638122426476984340" onclick="pdsClickLog('200000680', 'Item', {'ASN': 199, 'goodsCode': '2793644100'}); setStorageItem('199','2793644100','200');">레인보우 중목 라인양말_10+10켤레 세트 (할인특가)</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>43,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>12,900원</span></strong>
# <span><span class="sale"></span><em>70%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# <li id="itemidx200">
# <p class="no200" id="no200">200</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2791705618&amp;ver=638122426476984340" onclick="pdsClickLog('200000680', 'Item', {'ASN': 200, 'goodsCode': '2791705618'}); setStorageItem('200','2791705618','200');"><img alt="[길벗스쿨]길벗스쿨_언어천재 말놀이 세트(본책9권+꾸러미북1권+스티커북1권+말놀이 송카드)" class="lazy" data-original="//gdimg.gmarket.co.kr/2791705618/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/topica2018"><span class="view">판매자 다른상품 보기</span>토피카북스</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2791705618&amp;ver=638122426476984340" onclick="pdsClickLog('200000680', 'Item', {'ASN': 200, 'goodsCode': '2791705618'}); setStorageItem('200','2791705618','200');">[길벗스쿨]길벗스쿨_언어천재 말놀이 세트(본책9권+꾸러미북1권+스티커북1권+말놀이 송카드)</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>96,000원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>80,000원</span></strong>
# <span><span class="sale"></span><em>16%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>
# </ul>
# <div class="clear"></div>
# </div>
# </div>
# </div>
# <script language="javascript" type="text/javascript">
# 	var hashType = location.hash.substr(1);
# 	var gCode = "";
# 	var gChnCode = "";
# 	if (!$.isEmptyObject(gCode)) {
# 		if (gCode == "G01") { gChnCode = "1"; }
# 		if (gCode == "G02") { gChnCode = "2"; }
# 		if (gCode == "G03") { gChnCode = "3"; }
# 		if (gCode == "G04") { gChnCode = "4"; }
# 		if (gCode == "G05") { gChnCode = "8"; }
# 		if (gCode == "G06") { gChnCode = "9"; }
# 		if (gCode == "G07") { gChnCode = "5"; }
# 		if (gCode == "G08") { gChnCode = "6"; }
# 		if (gCode == "G09") { gChnCode = "7"; }
# 		if (gCode == "G10") { gChnCode = "10"; }
# 		if (gCode == "G11") { gChnCode = "11"; }
# 		if (gCode == "G12") { gChnCode = "12"; }
# 	}
#
# 	$(document).ready(function () {
#
# 			$('#groupMode').addClass('on');
# 			$("#groupMode > a").attr("aria-selected", "true");
# 				$('li.groupA').find("a").attr("role", "link").attr("aria-current", "page");
#
# 		if (hashType.indexOf('&') > 0) {
# 			setTimeout(function () { this.scroll(0, $("#" + hashType.substr(0, hashType.indexOf('&'))).offset().top) }, 1000);
# 		}
#
# 		ariaTab();
#
#
# 	});
#
# 	function showCategories(layerId) {
# 		document.getElementById(layerId).style.visibility = "visible";
# 	}
# 	function hideCategories(layerId) {
# 		document.getElementById(layerId).style.visibility = "hidden";
# 	}
#
# 	function toggleGroups() {
# 	}
#
# 	function toggleCategories() {
# 		$("#categoryTabC").toggle();
# 	}
#
# 	//G마켓 베스트란
# 	$('.box__info-gbest .button__questicon').on('click', function () {
# 		if ($('.box__info-gbest .box__layer-info--inner').css('display') !== 'none') {
# 			$(this).next().hide();
# 			$(this).parent().removeClass('z-higher');
# 			$(this).attr('aria-expanded', 'false');
# 		} else {
# 			$(this).next().show();
# 			$(this).parent().addClass('z-higher');
# 			$(this).attr('aria-expanded', 'true');
# 		}
# 	});
# 	$('.box__layer-info--inner .button__closed').on('click', function () {
# 		$(this).parent().hide();
# 		$(this).parent().parent('.box__info-gbest').removeClass('z-higher');
# 		$(this).parent().parent('.box__info-gbest').children(' .button__questicon').attr('aria-expanded', function (i, attr) {
# 			return attr == 'true' ? 'false' : 'true'
# 		});
# 		$(this).parent().prev().focus()
# 	});
# 	//그룹별,카테고리별 베스트란
# 	$('.box__info-category .button__questicon').on('click', function () {
# 		if ($('.box__info-category .box__layer-info--inner').css('display') !== 'none') {
# 			$(this).next().hide();
# 			$(this).parent().removeClass('z-higher');
# 			$(this).attr('aria-expanded', 'false');
# 		} else {
# 			$(this).next().show();
# 			$(this).parent().addClass('z-higher');
# 			$(this).attr('aria-expanded', 'true');
# 		}
# 	});
# 	$('.box__layer-info--inner .button__closed').on('click', function () {
# 		$(this).parent().hide();
# 		$(this).parents('.box__info-category .box__info-category').removeClass('z-higher');
# 		$(this).parent().parent('.box__info-category').removeClass('z-higher');
# 		$(this).parent().parent('.box__info-category').children(' .button__questicon').attr('aria-expanded', function (i, attr) {
# 			return attr == 'true' ? 'false' : 'true'
# 		});
#
#
# 		$(this).parent().prev().focus();
# 	});
#
# 	//상품 중복 링크 탐색 방지
# 	$("#gBestWrap .thumb").each(function () {
# 		$(this).find('a').attr("tabindex", "-1")
# 		$(this).find('a').attr("aria-hidden", "true")
# 	});
#
# 	// 3단계 카테고리 상세리스트
# 	$('.view_cate').on('click', function () {
# 		if ($(this).next().find('.layer').css('display') !== 'none') {
# 			$(this).next().find('.layer').hide();
# 			$(this).attr('aria-expanded', 'false');
# 		} else {
# 			$(this).next().find('.layer').show();
# 			$(this).attr('aria-expanded', 'true');
# 		}
# 	});
#
# </script>
# <script type="text/javascript">
# 	window.addEventListener('load', function () {
# 		setTimeout(function () {
# 			if (sessionStorage.getItem("itemScrollLoc") != null) {
# 				document.getElementById('itemidx' + sessionStorage.getItem("itemScrollLoc")).scrollIntoView();
# 				window.scrollBy(0, -80);
# 			}
# 		})
# 	});
#
#
# 	window.onpageshow = function (event) {
# 		if (event.persisted || (window.performance && window.performance.navigation.type == 2)) {
# 			if (sessionStorage.getItem('itemIndex') != null) {
# 				var itemidx = sessionStorage.getItem('itemIndex');
# 				displayCpcItemList();
# 				getBestCpcItem(sessionStorage.getItem('itemIndex'), sessionStorage.getItem('itemCnt'));
# 				if (sessionStorage.getItem("cpcItemno") == null) {
# 					removeStorageItem(1);
# 				}
# 				setScrollAllow();
# 			}
# 		}
# 		else {
# 			if (sessionStorage.getItem('itemno') != null) {
# 			} else {
# 				console.log('new page');
# 				$("#BestCpcLayer").hide();
# 				sessionStorage.removeItem('itemScrollLoc');
# 			}
# 		}
# 	};
#
# 	var setStorageItem = function (index, itemno, itemCnt) {
# 		setScrollStop();;
# 		sessionStorage.setItem('itemIndex', index);
# 		sessionStorage.setItem('itemCnt', itemCnt);
# 		sessionStorage.setItem('itemno', itemno);
# 		sessionStorage.setItem('itemScrollLoc', index)
#
# 		sessionStorage.removeItem('IsCpcmodule');
# 		sessionStorage.removeItem('cpcCategory');
# 	}
#
# 	var removeStorageItem = function (type) {
# 		if (type == 1)
# 		{
# 			sessionStorage.removeItem('itemIndex');
# 			sessionStorage.removeItem('itemCnt');
# 			sessionStorage.removeItem('itemno');
# 		} else {
# 			sessionStorage.removeItem('itemIndex');
# 			sessionStorage.removeItem('itemCnt');
# 			sessionStorage.removeItem('itemno');
# 			sessionStorage.removeItem('cpcItemno');
# 		}
# 	}
#
#
# 	var displayCpcItemList = function () {
# 		var itemIndex = 0;
# 		var storageItemIndex = Number(sessionStorage.getItem('itemIndex'));
# 		var itemCnt = Number(sessionStorage.getItem('itemCnt'));
#
# 		//set index
# 		if ((storageItemIndex % 4) == 0) {
# 			if (storageItemIndex < 4) {
# 				itemIndex = 4;
# 			} else {
# 				itemIndex = storageItemIndex;
# 			}
# 		} else {
# 			itemIndex = storageItemIndex + (4 - (storageItemIndex % 4));
# 		}
#
# 		if (itemIndex >= itemCnt) {
# 			itemIndex = storageItemIndex;
# 		}
#
# 		if (itemCnt > 100) { // all
# 			if (storageItemIndex > 196 && itemIndex == storageItemIndex) {
# 				itemIndex = 200;
# 			}
# 		} else { // category
# 			if (storageItemIndex > 96 && itemIndex == storageItemIndex) {
# 				itemIndex = 100;
# 			}
# 		}
# 		console.log(itemIndex + '/' + storageItemIndex + '/' + itemCnt);
# 		$('.no' + itemIndex).parent('li').after('<li class="list-item--relation"><div class="box__best-relation" id="BestCpcLayer" style="display:none"></div></li>');
# 	}
#
# 	var clickItemOn = function (storageItemIndex, itemNo) {
# 		$('#itemidx' + storageItemIndex).prepend('<span id="' + itemNo + '" class="box__corners-id"></span><div class="click"><span>클릭상품</span></div>');
# 	}
#
#
# 	//Best cpc items
# 	var getBestCpcItem = function (storageItemIndex, itemNo) {
# 		$.ajax({
# 			type: 'GET',
# 			dataType: 'html',
# 			url: '/Bestsellers/BestCpc?goodscode=' + sessionStorage.getItem('itemno') + '&cpcCategory=' + sessionStorage.getItem('cpcCategory'),
# 			async: true,
# 			success: function (res) {
# 				if (res && res != undefined && res != null && res != "") {
# 					$("#BestCpcLayer").html(res);
# 					$("#BestCpcLayer").show();
# 					clickItemOn(storageItemIndex, itemNo);
# 					bestRelationItem.init();
# 				} else {
# 					$(".click").remove();
# 					$("#BestCpcLayer").hide();
# 				}
# 			},
# 			error: function (result) {
# 			}
# 		});
# 	}
#
# 	/* best 연관상품 */
# 	bestRelationItem = (function () {
# 		var method = {};
# 		var obj = {};
# 		method.init = function () {
# 			method.setElement();
# 			method.tabChange();
# 		};
# 		method.setElement = function () {
# 			obj.gap = 16;
# 			obj.wrap = $('.box__best-relation');
# 			obj.tablist = obj.wrap.find('[role=tablist]');
# 			obj.itemlist = obj.wrap.find('.box__best-relation--list');
# 		};
# 		method.tabChange = function () {
# 			obj.tablist.each(function () {
# 				var $tab = $(this).find('[role=tab]');
# 				$tab.click(function () {
# 					var $lists = $(this).attr('aria-controls');
# 					$(this).attr({ 'aria-selected': 'true' }).siblings().attr({ 'aria-selected': 'false' });
# 				})
# 			})
# 		};
# 		return {
# 			init: method.init,
# 			tabChange: method.tabChange,
# 		};
# 	})();
#
# 	//IMPURL
# 	function sendImpLogForSuggest(impUrl) {
# 		if (sessionStorage.getItem('IsCpcmodule') == null) {
# 			if (typeof adprofiler === 'object' && typeof adprofiler.sendAd === 'function' && impUrl != '') {
# 				adprofiler.sendAd(impUrl);
# 				//console.log('ImpLog--->' + impUrl + '/' + sessionStorage.getItem("cpcItemno"));
# 			}
# 		}
# 	}
#
# 	function sendClickLogForSuggest(e, clickUrl, landingUrl, el) {
# 		var landingCb = function () { document.location.href = landingUrl; };
# 		if (typeof adprofiler === 'object' && typeof adprofiler.sendAd === 'function' && clickUrl != '') {
# 			e.preventDefault();
# 			setTimeout(landingCb, 0);
# 			adprofiler.sendAd(clickUrl, landingCb);
# 			//console.log('ImpClick--->' + clickUrl);
# 		}
# 	}
#
# 	function cpcItemClick(index, GoodsCode, serviceName, ClickSecureUrl, vipUrl, isAdItem) {
# 		pdsClickLog('200008518', 'Item', { 'device_type': '200', 'ASN': index, 'goodsCode': GoodsCode, 'service_name': serviceName });
# 		sessionStorage.setItem('cpcItemno', GoodsCode);
# 		sessionStorage.setItem('IsCpcmodule', 'Y');
# 		if (isAdItem == 'True') {
# 			sendClickLogForSuggest(event, ClickSecureUrl, vipUrl, this);
# 		}
# 	}
#
# 	function setScrollLoc (itemidx) {
# 		document.getElementById('itemidx' + itemidx).scrollIntoView();
# 		//window.scrollBy(0, -30);
# 	}
#
# 	var setScrollStop = function () {
# 		$('#container').on('scroll touchmove mousewheel', function (event) {
# 			event.preventDefault();
# 			event.stopPropagation();
# 			return false;
# 		});
# 	}
#
# 	var setScrollAllow = function () {
# 		$('#container').off('scroll touchmove mousewheel');
# 	}
#
# </script>
# </div>
# <script src="https://script.gmarket.co.kr/pc/js/api/jquery.carouFredSel.js" type="text/javascript"></script>
# <script src="//script.gmarket.co.kr/pc/js/ko/common.js" type="text/javascript"></script>
# <script src="//script.gmarket.co.kr/_Net/js/corners/Gmarket.Corners.Bestsellers.js" type="text/javascript"></script>
# <script src="//script.gmarket.co.kr/js/common/ubprofiler_gmkt.js?t=20140305" type="text/javascript"></script>
# <script src="//script.gmarket.co.kr/pc/js/common/kr/lib/improveAccessibility.js" type="text/javascript"></script>
# <script src="//script.gmarket.co.kr/js/common/ats_gmkt.js" type="text/javascript"></script>
# <div id="footer">
# </div>
# <script type="text/javascript">
# 	DesktopLayout.render([{
# 		name: "Footer",
# 		params: {"type":"default"},
# 		container: document.getElementById("footer"),
# 	}]);
# </script>
# </div></body>
# </html>

# %%
elements = dom.select('#gBestWrap > div > div:nth-child(5) > div > ul > li')
len(elements)
# id가 없는 걸 선택해야한다.
# Out:
# 200

# %%
elements[0]
# Out:
# <li class="first" id="itemidx1">
# <p class="no1" id="no1">1</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2628342593&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2628342593'}); setStorageItem('1','2628342593','200');"><img alt="[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음" class="lazy" data-original="//gdimg.gmarket.co.kr/2628342593/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/allmaeil"><span class="view">판매자 다른상품 보기</span>매일유업공식판매업체</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2628342593&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2628342593'}); setStorageItem('1','2628342593','200');">[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>33,800원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>23,700원</span></strong>
# <span><span class="sale"></span><em>29%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>

# %%
element = elements[0]

# %%
element
# Out:
# <li class="first" id="itemidx1">
# <p class="no1" id="no1">1</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2628342593&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2628342593'}); setStorageItem('1','2628342593','200');"><img alt="[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음" class="lazy" data-original="//gdimg.gmarket.co.kr/2628342593/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/allmaeil"><span class="view">판매자 다른상품 보기</span>매일유업공식판매업체</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2628342593&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2628342593'}); setStorageItem('1','2628342593','200');">[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>33,800원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>23,700원</span></strong>
# <span><span class="sale"></span><em>29%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>

# %%
data = {
    'title' : element.select_one('.itemname').text,
    'link' : element.select_one('.itemname').get('href'),
    'img' : 'http:' + element.select_one('img').get('data-original'),
    'o-price' : element.select_one('.o-price').text,
    's-price' : element.select_one('.s-price').text.strip().split('\n')[0],
}
data
# Out:
# {'title': '[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=2628342593&ver=638122426476828321',
#  'img': 'http://gdimg.gmarket.co.kr/2628342593/still/300?ver=2023021714',
#  'o-price': '정가33,800원',
#  's-price': '할인가23,700원'}

# %%
element
# Out:
# <li class="first" id="itemidx1">
# <p class="no1" id="no1">1</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=2628342593&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2628342593'}); setStorageItem('1','2628342593','200');"><img alt="[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음" class="lazy" data-original="//gdimg.gmarket.co.kr/2628342593/still/300?ver=2023021714" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/allmaeil"><span class="view">판매자 다른상품 보기</span>매일유업공식판매업체</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2628342593&amp;ver=638122426476828321" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2628342593'}); setStorageItem('1','2628342593','200');">[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음</a>
# <div class="item_price">
# <div class="o-price"><span class="for-a11y">정가</span><span>33,800원</span></div>
# <div class="s-price">
# <span class="for-a11y">할인가</span><strong><span>23,700원</span></strong>
# <span><span class="sale"></span><em>29%</em></span>
# </div>
# <div class="icon">
# <img alt="무료배송" src="//pics.gmkt.kr/pc/ko/corner/gbest/ic_freeshipping.gif"/>
# </div>
# </div>
# </li>

# %%
data = []
for element in elements:
    data.append({
        'title' : element.select_one('.itemname').text,
        'link' : element.select_one('.itemname').get('href'),
        'img' : 'http:' + element.select_one('img').get('data-original'),
        'o-price' : element.select_one('.o-price').text,
        's-price' : element.select_one('.s-price').text.strip().split('\n')[0],
    })
data[:3]
# Out:
# [{'title': '[매일유업]매일 상하멸균우유/케일주스/요미요미24팩모음',
#   'link': 'http://item.gmarket.co.kr/Item?goodscode=2628342593&ver=638122426476828321',
#   'img': 'http://gdimg.gmarket.co.kr/2628342593/still/300?ver=2023021714',
#   'o-price': '정가33,800원',
#   's-price': '할인가23,700원'},
#  {'title': '[피셔프라이스]피셔프라이스 러닝 푸드트럭',
#   'link': 'http://item.gmarket.co.kr/Item?goodscode=1998535842&ver=638122426476828321',
#   'img': 'http://gdimg.gmarket.co.kr/1998535842/still/300?ver=2023021714',
#   'o-price': '정가210,000원',
#   's-price': '할인가99,000원'},
#  {'title': '[나이키키즈](대구신세계)[나이키키즈] (105~170) 조던 썸머 상/하의세트 세일가',
#   'link': 'http://item.gmarket.co.kr/Item?goodscode=2772877848&ver=638122426476828321',
#   'img': 'http://gdimg.gmarket.co.kr/2772877848/still/300?ver=2023021714',
#   'o-price': '정가58,000원',
#   's-price': '할인가45,820원'}]

# %%
data = []
for element in elements:
    data.append({
        'title' : element.select_one('.itemname').text,
        'link' : element.select_one('.itemname').get('href'),
        'img' : 'http:' + element.select_one('img').get('data-original'),
        'o-price' : element.select_one('.o-price').text,
        's-price' : element.select_one('.s-price').text.strip().split('\n')[0],
    })
df = pd.DataFrame(data)
df.tail(2)
# Out:
#                                                  title  \
# 198                     레인보우 중목 라인양말_10+10켤레 세트 (할인특가)
# 199  [길벗스쿨]길벗스쿨_언어천재 말놀이 세트(본책9권+꾸러미북1권+스티커북1권+말놀이 ...
#
#                                                   link  \
# 198  http://item.gmarket.co.kr/Item?goodscode=27936...
# 199  http://item.gmarket.co.kr/Item?goodscode=27917...
#
#                                                    img    o-price     s-price
# 198  http://gdimg.gmarket.co.kr/2793644100/still/30...  정가43,000원  할인가12,900원
# 199  http://gdimg.gmarket.co.kr/2791705618/still/30...  정가96,000원  할인가80,000원

# %%
df[20:40]
# Out:
#                                                 title  \
# 20                [압타밀]압타밀 프로푸트라 HMO 2단계 800g x 6통 세트
# 21       [도루코]베이직 파스텔 주방가위 1+1특가(색상랜덤) + 집게증정 /우수한절삭력
# 22                             [일동후디스]후디스 아이음료 과자 모음전
# 23                               도드람한돈 생 삼겹살 500g 구이용
# 24                        [구글플레이]기프트코드 5만원 / 구글 기프트카드
# 25             [닥터지]닥터지 블랙 스네일 달팽이크림 50ml 1+1_A005956
# 26                    [오뚜기]오뚜기 가벼운참치 라이트스탠다드 135GX12개
# 27                아침이슬사과 22년 햇 부사 가정용 중대과 4.5kg(22과내)
# 28                          쌈빡김치 국내산 100% 전라도 파김치 1kg
# 29  http://gdimg.gmarket.co.kr/2375673537/still/30...  정가10,000원    할인가9,400원
# 30  http://gdimg.gmarket.co.kr/1648956331/still/30...  정가15,800원    할인가7,900원
# 31  http://gdimg.gmarket.co.kr/1927983843/still/30...              할인가25,900원
# 32  http://gdimg.gmarket.co.kr/2397297134/still/30...              할인가29,900원
# 33  http://gdimg.gmarket.co.kr/2665894484/still/30...  정가22,200원   할인가19,980원
# 34  http://gdimg.gmarket.co.kr/2733484740/still/30...              할인가10,500원
# 35  http://gdimg.gmarket.co.kr/2762352402/still/30...  정가16,900원   할인가15,440원
# 36  http://gdimg.gmarket.co.kr/2770486099/still/30...  정가39,900원   할인가36,110원
# 37  http://gdimg.gmarket.co.kr/2619820926/still/30...              할인가26,500원
# 38  http://gdimg.gmarket.co.kr/2742067082/still/30...  정가25,800원   할인가11,610원
# 39  http://gdimg.gmarket.co.kr/1481853791/still/30...  정가50,000원   할인가28,000원

# %%
# update : 데이터선택 = 수정할 데이터
df[df['o-price'] == '']
# Out:
#                                                  title  \
# 12                           [쉬크]쉬크 하이드로5 베이스 날14입+면도기
# 20                 [압타밀]압타밀 프로푸트라 HMO 2단계 800g x 6통 세트
# 21        [도루코]베이직 파스텔 주방가위 1+1특가(색상랜덤) + 집게증정 /우수한절삭력
# 23                                도드람한돈 생 삼겹살 500g 구이용
# 31                     [물고기삼촌]양꼬치 양깍두기 양고기 1kg  + 쯔란1봉
# 32                   [올리빙]도트 스탠드 분리수거함 3단 다용도 수납함 105L
# 34   [G클럽]니트릴장갑 100매+100매(200매)_화이트 블루 그레이 베이직블랙 요리...
# 37   정육생활 최현석의 부채살 구이용 200g x 4팩 (중복쿠폰가21200)+우삼겹20...
# 57            [테이팩스]박스테이프 벌크 황색 OPP 경포장 48mm x 40M 20개
# 63                   [인플루엔셜](카드사 15% 할인+사은품 증정) 파친코 세트
# 74        Singles 싱글즈 C형 (월간) : 3월 2023 : 표지 : 강다니엘  싱
# 77        Singles 싱글즈 B형 (월간) : 3월 2023 : 표지 : 강다니엘  싱
# 78        Singles 싱글즈 A형 (월간) : 3월 2023 : 표지 : 강다니엘  싱
# 97                      우삼겹 미국산 고급육 250gx4팩 샤브/구이용/소포장
# 102            [Gfresh]누리푸드 프리미엄 목살과 앞다리살 주물럭용 250gX6팩
# 112    [아트조이]DIY 보석십자수 (캔버스형) vs 명화그리기 vs 미니어처하우스 취미대전
# 114           [바라던]6 7 8번 꽃갈비 부위를 사용한 LA갈비 1kg 99%기름손질
# 121                               일회용 종이컵 2000개 (무료배송)
# 128                             [햇반]CJ 햇반 210g 36개 1박스
# 130                          [네스카페]수프리모 오리지널 300T 무료배송
# 134                              [스파클]스파클생수 500ml 100병
# 137                   [리큐]리큐 진한겔 꿉꿉한냄새 싹 2.1L X6개 (겸용)
# 138                     무형광 미쁘핸드타월 핸드타올2겹  5000매 페이퍼타올
# 141                          기적의 초특가트루마리 순수휴지 30미터 90롤
# 146                   [CJ제일제당]얼티브 오리지널 190ml x24입 (박스)
# 184  http://gdimg.gmarket.co.kr/2791959974/still/30...           할인가24,500원

# %%
# update : 데이터선택 = 수정할 데이터

idx = df[df['o-price'] == ''].index
df['o-price'].loc[idx] = df['s-price'].loc[idx]
df[20:40].head(2)
# Out:
#                                            title  \
# 20           [압타밀]압타밀 프로푸트라 HMO 2단계 800g x 6통 세트
# 21  [도루코]베이직 파스텔 주방가위 1+1특가(색상랜덤) + 집게증정 /우수한절삭력
#
#                                                  link  \
# 20  http://item.gmarket.co.kr/Item?goodscode=25037...
# 21  http://item.gmarket.co.kr/Item?goodscode=21508...
#
#                                                   img      o-price  \
# 20  http://gdimg.gmarket.co.kr/2503772943/still/30...  할인가199,000원
# 21  http://gdimg.gmarket.co.kr/2150845686/still/30...    할인가7,900원
#
#         s-price
# 20  할인가199,000원
# 21    할인가7,900원

# %%
# regex : 정규표현식
# 문자열 데이터를 특정 패턴으로 처리할때 사용하는 문법

# %%
# 정규표현식
# 가독성이 떨어짐
import re
price = '할인가1,111,800원'
re.findall('[0-9,]+',price)[0]
# Out:
# '1,111,800'

# %%
df['o-price'] = df['o-price'].apply(lambda price: re.findall('[0-9,]+', price)[0]) 
df['s-price'] = df['s-price'].apply(lambda price: re.findall('[0-9,]+', price)[0]) 
df.tail(2)
# Out:
#                                                  title  \
# 198                     레인보우 중목 라인양말_10+10켤레 세트 (할인특가)
# 199  [길벗스쿨]길벗스쿨_언어천재 말놀이 세트(본책9권+꾸러미북1권+스티커북1권+말놀이 ...
#
#                                                   link  \
# 198  http://item.gmarket.co.kr/Item?goodscode=27936...
# 199  http://item.gmarket.co.kr/Item?goodscode=27917...
#
#                                                    img o-price s-price
# 198  http://gdimg.gmarket.co.kr/2793644100/still/30...  43,000  12,900
# 199  http://gdimg.gmarket.co.kr/2791705618/still/30...  96,000  80,000

# %%
txt = '저의 이메일 주소는 pdj1224@gmail.com과 pdj1224@naver.com 입니다.'
re.findall('[a-zA-Z0-9.]+@[a-z]+\.[a-z]+',txt)
# Out:
# ['pdj1224@gmail.com', 'pdj1224@naver.com']

# %% [markdown]
# #### 4. download image

# %%
# 이미지 파일 저장할 디텍토리

# %%
import os
os.makedirs('data')

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EE2D-1664
#
#  C:\Users\User\Documents\GitHub\KT_python_jupyter_notebook\2023.02.17\day2 디렉터리
#
# 2023-02-17  오후 03:47    <DIR>          .
# 2023-02-17  오후 03:47    <DIR>          ..
# 2023-02-17  오후 02:36    <DIR>          .ipynb_checkpoints
# 2023-02-17  오후 01:41            19,736 01_html.ipynb
# 2023-02-17  오후 02:10            12,470 02_css_selector.ipynb
# 2023-02-17  오후 02:36            11,656 03_naver_relational_keywords.ipynb
# 2023-02-17  오후 03:46           465,131 04_gmarket.ipynb
# 2023-02-17  오후 02:38             2,497 05_selenium.ipynb
# 2023-02-17  오후 03:47    <DIR>          data
# 2023-02-17  오전 11:49           679,441 zzzzzz.png
#                6개 파일           1,190,931 바이트
#                4개 디렉터리  105,787,711,488 바이트 남음

# %%
import os
dir_name = 'data'
if not os.path.exists(dir_name)
os.makedirs('data')
# Out:
#   Cell In[47], line 3
#     if not os.path.exists(dir_name)
#                                    ^
# SyntaxError: invalid syntax

# %%
df.tail(1)
# Out:
#                                                  title  \
# 199  [길벗스쿨]길벗스쿨_언어천재 말놀이 세트(본책9권+꾸러미북1권+스티커북1권+말놀이 ...
#
#                                                   link  \
# 199  http://item.gmarket.co.kr/Item?goodscode=27917...
#
#                                                    img o-price s-price
# 199  http://gdimg.gmarket.co.kr/2791705618/still/30...  96,000  80,000

# %%
img_link = df.loc[0,'img']
print(img_link)
# Out:
# http://gdimg.gmarket.co.kr/2628342593/still/300?ver=2023021714

# %%
response = requests.get(img_link)
response
# Out:
# <Response [200]>

# %%
with open('data/test.png','wb') as file:
    file.write(response.content)

# %%
# %ls data
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EE2D-1664
#
#  C:\Users\User\Documents\GitHub\KT_python_jupyter_notebook\2023.02.17\day2\data 디렉터리
#
# 2023-02-17  오후 03:52    <DIR>          .
# 2023-02-17  오후 03:52    <DIR>          ..
# 2023-02-17  오후 03:52            33,866 test.png
#                1개 파일              33,866 바이트
#                2개 디렉터리  105,787,772,928 바이트 남음

# %%
# pillow : 파이썬에서 이미지 전처리를 하는 패키지
from PIL import Image as pil

# %%
pil.open('data/test.png')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300>

# %%
# for idx, data in df[:20].iterrows(): filename = '0' * (3 - len(str(idx))) + str(idx) filename = f'data/{filename}.png' print(idx, data['img'], filename) response = requests.get(data['img']) with open(filename, 'wb') as file: file.write(response.content)

# %%
for idx, data in df[:20].iterrows(): 
    filename = '0' * (3 - len(str(idx))) + str(idx)
    filename = f'data/{filename}.png' 
    print(idx, data['img'], filename)
    response = requests.get(data['img'])
    with open(filename,'wb') as file:
        file.write(response.content)
# Out:
# 0 http://gdimg.gmarket.co.kr/2628342593/still/300?ver=2023021714 data/000.png
# 1 http://gdimg.gmarket.co.kr/1998535842/still/300?ver=2023021714 data/001.png
# 2 http://gdimg.gmarket.co.kr/2772877848/still/300?ver=2023021714 data/002.png
# 3 http://gdimg.gmarket.co.kr/2767818438/still/300?ver=2023021714 data/003.png
# 4 http://gdimg.gmarket.co.kr/2780877061/still/300?ver=2023021714 data/004.png
# 5 http://gdimg.gmarket.co.kr/2762345389/still/300?ver=2023021714 data/005.png
# 6 http://gdimg.gmarket.co.kr/182821824/still/300?ver=2023021714 data/006.png
# 7 http://gdimg.gmarket.co.kr/1977052165/still/300?ver=2023021714 data/007.png
# 8 http://gdimg.gmarket.co.kr/2635078880/still/300?ver=2023021714 data/008.png
# 9 http://gdimg.gmarket.co.kr/2347262038/still/300?ver=2023021714 data/009.png
# 10 http://gdimg.gmarket.co.kr/2090522905/still/300?ver=2023021714 data/010.png
# 11 http://gdimg.gmarket.co.kr/2779014323/still/300?ver=2023021714 data/011.png
# 12 http://gdimg.gmarket.co.kr/2246382810/still/300?ver=2023021714 data/012.png
