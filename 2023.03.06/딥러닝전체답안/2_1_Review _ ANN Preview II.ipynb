# %% [markdown]
# # 1일차 Review : 같은 문제 다시 풀어보기
# ---
# - 학습은 10번만!

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
x = cancer.data
y = cancer.target

# %%
x.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
###########################
# train set / test set 분리
# 조건 1. test set : 20%
# 조건 2. 난수 고정 : 2023
###########################
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =\
    train_test_split(x, y, test_size=0.2, random_state=2023)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((455, 30), (455,), (114, 30), (114,))

# %%
#####################
# 라이브러리 불러오기
#####################
import tensorflow as tf
from tensorflow import keras

# %%
########
# 모델링 : Sequential API
########
# 1번. 세션 클리어
keras.backend.clear_session()
# 2번. 모델 선언
model = keras.models.Sequential()
# 3번. 레이어 조립
model.add(keras.layers.Input(shape=(30,)) )
model.add(keras.layers.Dense(1, activation='sigmoid'))
# 4번. 컴파일
model.compile(loss=keras.losses.binary_crossentropy, metrics=['accuracy'],
              optimizer='adam')
# 양념
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 31
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x_train, y_train, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 1s 2ms/step - loss: 69.8075 - accuracy: 0.3714
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 57.9719 - accuracy: 0.3692
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 46.7149 - accuracy: 0.3626
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 36.5187 - accuracy: 0.3319
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 28.8273 - accuracy: 0.2703
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 25.5891 - accuracy: 0.1846
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 24.5497 - accuracy: 0.1297
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 23.8248 - accuracy: 0.1275
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 23.2371 - accuracy: 0.1297
# Epoch 10/10
# 15/15 [==============================] - 0s 3ms/step - loss: 22.6876 - accuracy: 0.1319

# %%
###########
# 모델 예측
###########
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
y_pred[:10]
# Out:
# array([[9.9999982e-01],
#        [9.9396306e-01],
#        [6.1429100e-04],
#        [1.0000000e+00],
#        [1.0000000e+00],
#        [1.0000000e+00],
#        [1.6913550e-02],
#        [2.6405126e-01],
#        [2.5866838e-11],
#        [1.1903414e-04]], dtype=float32)

# %%
y_test[:10]
# Out:
# array([0, 0, 1, 0, 0, 0, 1, 1, 1, 1])

# %% [markdown]
# # 히든 레이어 추가하여 모델링!
# ---
# - 조건
#     - 히든 레이어 2개를 추가하여 다시 모델링!
#     - 히든 레이어 노드 수 : 32
#     - 히든 레이어 activation = 'relu'

# %%
x_train.shape, y_train.shape
# Out:
# ((455, 30), (455,))

# %%
########
# 모델링 : Sequential API
########
# 세션 클리어
keras.backend.clear_session()
# 모델 선언
model = keras.models.Sequential()
# 레이어 조립
model.add( keras.layers.Input(shape=(30,)))
model.add( keras.layers.Dense(32, activation='relu'))
model.add( keras.layers.Dense(32, activation='relu'))
model.add( keras.layers.Dense(1, activation='sigmoid'))
# 컴파일
model.compile(loss='binary_crossentropy', metrics=['accuracy'],
              optimizer='adam')
# 요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                992
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,081
# Trainable params: 2,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x_train, y_train, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 1s 4ms/step - loss: 4.6595 - accuracy: 0.5780
# Epoch 2/10
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5985 - accuracy: 0.7736
# Epoch 3/10
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3333 - accuracy: 0.8659
# Epoch 4/10
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2260 - accuracy: 0.9055
# Epoch 5/10
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2488 - accuracy: 0.9011
# Epoch 6/10
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2092 - accuracy: 0.9121
# Epoch 7/10
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2208 - accuracy: 0.9231
# Epoch 8/10
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2058 - accuracy: 0.9297
# Epoch 9/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2257 - accuracy: 0.9121
# Epoch 10/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2326 - accuracy: 0.9077

# %%
###########
# 모델 예측
###########
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
y_pred[:10]
# Out:
# array([[4.2797636e-02],
#        [9.7506011e-01],
#        [8.9765751e-01],
#        [7.1851473e-04],
#        [9.3551389e-11],
#        [3.6119778e-05],
#        [9.0840489e-01],
#        [6.8986917e-01],
#        [8.7188494e-01],
#        [9.9740416e-01]], dtype=float32)

# %%
y_test[:10]
# Out:
# array([0, 0, 1, 0, 0, 0, 1, 1, 1, 1])
